# %% [markdown]
# <a href="https://colab.research.google.com/github/tlinhnguyen2308/Logic_mo/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
data=pd.read_csv('/content/1.01. Simple linear regression.csv')
data.head()
y=data['GPA']
x1=data['SAT']
plt.scatter(x1,y)
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X=pd.DataFrame(data['SAT']),y=data['GPA'])
print('Hệ số góc:',model.coef_)
print('Giao giữa đường hồi quy và trục tung:',model.intercept_)
# Out:
# Hệ số góc: [0.00165569]
# Giao giữa đường hồi quy và trục tung: 0.2750402996602799

# %%
data.plot(kind='scatter', x='SAT', y='GPA', figsize=(9,9), color='blue', xlim=(1500, 2200), ylim=(2, 4))
# Out:
# <Axes: xlabel='SAT', ylabel='GPA'>

# %%
y_pred=model.predict(X=pd.DataFrame(data['SAT']))
data.plot(kind='scatter', x='SAT', y='GPA', figsize=(9,9), color='blue', xlim=(1500, 2200), ylim=(2, 4))
plt.plot(data['SAT'],y_pred)

# %%
model.score(X=pd.DataFrame(data['SAT']),y=data['GPA'])
# Out:
# 0.40600391479679754

# %%
x1=[[1900],[2000]]
y1=model.predict(x1)
print(y1)
# Out:
# [3.42084759 3.5864164 ]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/Salary_Data.csv')
dataset.head()
dataset.shape
# Out:
# (30, 2)

# %%
x=dataset.drop(['Salary'],axis=True)
y=dataset['Salary']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((24, 1), (6, 1), (24,), (6,))

# %%
sns.pairplot(dataset)

# %%
plt.plot(x_train,y_train,'r.',label='train_data')
plt.xlabel('X_train')
plt.ylabel('Y_train')
plt.legend()
plt.show()

# %%
plt.plot(x_test,y_test,'g.',label='test_data')
plt.xlabel('X_test')
plt.ylabel('Y_test')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test).round(1)
calculation=pd.DataFrame(np.c_[y_test,y_pred], columns=["Original Salary","Predict Salary"])
calculation
# Out:
#    Original Salary  Predict Salary
# 0         112635.0        115790.2
# 1          67938.0         71498.3
# 2         113812.0        102596.9
# 3          83088.0         75267.8
# 4          64445.0         55477.8
# 5          57189.0         60189.7

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Experience (Train set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
import pandas as pd
data=pd.read_csv('/content/mtcars.csv')
data.head()
# Out:
#     mpg   disp   hp     wt
# 0  21.0  160.0  110  2.620
# 1  21.0  160.0  110  2.875
# 2  22.8  108.0   93  2.320
# 3  21.4  258.0  110  3.215
# 4  18.7  360.0  175  3.440

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation= data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
#khối lượng càng tăng sô lượng đi được càng giảm, thể tích bù đốt càng tăng
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
import pandas as pd
#Mô hình ban đầu
regression_model=linear_model.LinearRegression()
#Huấn luyện mô hình sử dụng dữ liệu mtcars
regression_model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
#Giá trị coef của mô hình
print(regression_model.coef_)
#Giá trị intercept của mô hình
print(regression_model.intercept_)
# Out:
# [-5.34447157]
# 37.28512616734204

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print('Hệ số góc:',model.coef_)
print('Giao giữa đường hồi quy và trục tung:',model.intercept_)
# Out:
# Hệ số góc: [-5.34447157]
# Giao giữa đường hồi quy và trục tung: 37.28512616734204

# %%
regression_model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])
# Out:
# 0.7528327936582646

# %%
train_prediction= regression_model.predict(X=pd.DataFrame(data["wt"]))
residuals=data["mpg"]-train_prediction
residuals.describe() #sai số
# Out:
# count    3.200000e+01
# mean    -8.215650e-15
# std      2.996352e+00
# min     -4.543151e+00
# 25%     -2.364709e+00
# 50%     -1.251956e-01
# 75%      1.409561e+00
# max      6.872711e+00
# Name: mpg, dtype: float64

# %%
y_pred= regression_model.predict(X=pd.DataFrame(data["wt"]))
error=data['mpg'] - y_pred
print(error)
# Out:
# 0    -2.282611
# 1    -0.919770
# 2    -2.085952
# 3     1.297350
# 4    -0.200144
# 5    -0.693255
# 6    -3.905363
# 7     4.163738
# 8     2.349959
# 9     0.299856
# 10   -1.100144
# 11    0.866873
# 12   -0.050247
# 13   -1.883024
# 14    1.173350
# 15    2.103288
# 16    5.981074
# 17    6.872711
# 18    1.746195
# 19    6.421979
# 20   -2.611004
# 21   -2.972586
# 22   -3.726866
# 23   -3.462355
# 24    2.464367
# 25    0.356426
# 26    0.152043
# 27    1.201059
# 28   -4.543151
# 29   -2.780940
# 30   -3.205363
# 31   -1.027495
# Name: mpg, dtype: float64

# %%
data.plot(kind='scatter', x='wt', y='mpg', figsize=(9,9), color='black', xlim=(0,7))
#Vẽ đường hồi quy
plt.plot(data["wt"],#biến vào
         train_prediction,#giá trị tiên đoán
         color="blue");

# %%
poly_model=linear_model.LinearRegression()
predictors=pd.DataFrame([data["wt"],data["wt"]**2]).T
poly_model.fit(X=predictors,y=data['mpg'])
print("Intercept của mô hình:")
print(poly_model.intercept_)
print("Coefficiemts của mô hình:")
print(poly_model.coef_)
print("Độ chính xác của mô hình:")
print(poly_model.score(X=predictors,y=data['mpg']))
# Out:
# Intercept của mô hình:
# 49.93081094945181
# Coefficiemts của mô hình:
# [-13.38033708   1.17108689]
# Độ chính xác của mô hình:
# 0.8190613581384094

# %%
poly_line_range=np.arange(1.5,5.5,0.1)
poly_predictors=pd.DataFrame(np.array([poly_line_range,poly_line_range**2]).T)
y_values=poly_model.predict(poly_predictors)
data.plot(kind='scatter', x='wt', y='mpg', figsize=(9,9), color='black', xlim=(0,7))
plt.plot(poly_line_range,y_values,color='blue')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
poly_model=linear_model.LinearRegression()
predictors=pd.DataFrame([data["wt"],data["wt"]**2,data["wt"]**3,data["wt"]**4,data["wt"]**5,data["wt"]**6,data["wt"]**7,data["wt"]**8,data["wt"]**9,data["wt"]**10]).T
poly_model.fit(X=predictors,y=data['mpg'])
print("Intercept của mô hình:")
print(poly_model.intercept_)
print("Coefficiemts của mô hình:")
print(poly_model.coef_)
print("Độ chính xác của mô hình:")
print(poly_model.score(X=predictors,y=data['mpg']))
# Out:
# Intercept của mô hình:
# -14921.11995188375
# Coefficiemts của mô hình:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Độ chính xác của mô hình:
# 0.8702106571479111

# %%
poly_line_range=np.arange(1.5,5.45,0.01)
poly_predictors=pd.DataFrame(np.array([poly_line_range,poly_line_range**2,poly_line_range**3,poly_line_range**4,poly_line_range**5,poly_line_range**6,poly_line_range**7,poly_line_range**8,poly_line_range**9,poly_line_range**10]).T)
y_values=poly_model.predict(X=poly_predictors)
data.plot(kind='scatter', x='wt', y='mpg', figsize=(9,9), color='black', xlim=(0,7))
plt.plot(poly_line_range,y_values,color='blue')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
data=pd.read_csv('/content/advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
correlation=data.corr()
print(correlation)
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(data)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X=pd.DataFrame(data['TV']),y=data['Sales'])
# Out:
# LinearRegression()

# %%
print(model.intercept_,model.coef_)
model.score(X=pd.DataFrame(data['TV']),y=data['Sales'])
# Out:
# 6.974821488229891 [0.05546477]
# 0.8121757029987414

# %%
data.plot(kind='scatter', x='TV', y='Sales', figsize=(9,9), color='black', xlim=(0,7))
#Vẽ đường hồi quy
# Calculate train_prediction using the current model and data
train_prediction = model.predict(X=pd.DataFrame(data['TV']))
plt.plot(data["TV"],#biến vào
         train_prediction,#giá trị tiên đoán
         color="blue");

# %%
poly_model=linear_model.LinearRegression()
predictors=pd.DataFrame([data["TV"],data["TV"]**2]).T
poly_model.fit(X=predictors,y=data['Sales'])
print("Intercept của mô hình:")
print(poly_model.intercept_)
print("Coefficiemts của mô hình:")
print(poly_model.coef_)
print("Độ chính xác của mô hình:")
print(poly_model.score(X=predictors,y=data['Sales']))
# Out:
# Intercept của mô hình:
# 5.858462162458922
# Coefficiemts của mô hình:
# [ 7.94447491e-02 -8.32211162e-05]
# Độ chính xác của mô hình:
# 0.8224919782956169

# %%
print(model.intercept_,model.coef_)
model.score(X=pd.DataFrame(data['TV']),y=data['Sales'])
# Out:
# 6.974821488229891 [0.05546477]
# 0.8121757029987414

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
startup=pd.read_csv('/content/50_Startups.csv')
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.pairplot(dataset)

# %%
x=dataset.drop(['State'],axis=True)
y=dataset['State']
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
startup_model=linear_model.LinearRegression()
Startup=pd.DataFrame([startup['R&D Spend']]).T
startup_model.fit(X=Startup, y=startup['Profit'])
print("Intercept cua mo hinh:", startup_model.intercept_)
print("Coefficients cua mo hinh:", startup_model.coef_)
print("Do chinh xac cua mo hinh:", startup_model.score(X=Startup, y=startup['Profit']))
# Out:
# Intercept cua mo hinh: 49032.89914125215
# Coefficients cua mo hinh: [0.85429137]
# Do chinh xac cua mo hinh: 0.9465353160804393

# %%
startup_model=linear_model.LinearRegression()
Startup=pd.DataFrame([startup['R&D Spend'], startup['Administration']]).T
startup_model.fit(X=Startup, y=startup['Profit'])
print("Intercept cua mo hinh:", startup_model.intercept_)
print("Coefficients cua mo hinh:", startup_model.coef_)
print("Do chinh xac cua mo hinh:", startup_model.score(X=Startup, y=startup['Profit']))
# Out:
# Intercept cua mo hinh: 54886.620627563
# Coefficients cua mo hinh: [ 0.86211798 -0.05299543]
# Do chinh xac cua mo hinh: 0.9478129385009173

# %%
startup_model=linear_model.LinearRegression()
Startup=pd.DataFrame([startup['R&D Spend'], startup['Administration'], startup['Marketing Spend']]).T
startup_model.fit(X=Startup, y=startup['Profit'])
print("Intercept cua mo hinh:", startup_model.intercept_)
print("Coefficients cua mo hinh:", startup_model.coef_)
print("Do chinh xac cua mo hinh:", startup_model.score(X=Startup, y=startup['Profit']))
# Out:
# Intercept cua mo hinh: 50122.19298986526
# Coefficients cua mo hinh: [ 0.80571505 -0.02681597  0.02722806]
# Do chinh xac cua mo hinh: 0.9507459940683246

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
iris=datasets.load_iris()
x=iris.data
y=iris.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
svm_model=SVC(kernel='linear')
svm_model.fit(x_train,y_train)
y_pred=svm_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
svm_rbf=SVC(kernel='rbf',gamma='scale')
svm_rbf.fit(x_train,y_train)
y_pred_rbf=svm_rbf.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"RBF Kernel Accuracy: {accuracy_score(y_test,y_pred_rbf):.2f}")
# Out:
# RBF Kernel Accuracy: 1.00
